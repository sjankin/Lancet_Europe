# %%
#load necessary packages
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt

# %%
#load data
data=pd.read_csv("/YOUR PATH/demographer_german.txt")

# %%
#build the plot for gender
data["gender"].value_counts(normalize=True).plot(kind="bar", rot=0, color="grey")
plt.xlabel("Gender")
plt.ylabel("Percentage")
plt.show()

# %%
#build the plot for age
data["age"].value_counts(normalize=True).plot(kind="bar", rot=0, color="grey")
plt.xlabel("Age")
plt.ylabel("Percentage")
plt.xticks([0,1,2,3],['40 and older', '18 and younger', '30-39', '19-29'])
plt.show()
